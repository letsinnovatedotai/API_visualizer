# %%
df
# Out:
#        Method                         Path
# 0        POST           /api/auth/send-otp
# 1        POST         /api/auth/verify-otp
# 2        POST             /api/auth/signup
# 3        POST      /api/auth/google-signin
# 4        POST              /api/auth/login
# 5        POST   /api/auth/token_validation
# 6        POST             /api/auth/logout
# 7        POST       /api/browser_bookmarks
# 8        POST               /api/bookmarks
# 9         GET               /api/bookmarks
# 10     DELETE               /api/bookmarks
# 11        PUT               /api/bookmarks
# 12       POST  /api/bookmarks/validate_url
# 13        GET        /api/bookmarks/search
# 14       POST         /api/bookmarks/views
# 15       POST    /api/bookmarks/favourites
# 16     DELETE    /api/bookmarks/favourites
# 17        GET    /api/bookmarks/favourites
# 18       POST             /api/collections
# 19        GET             /api/collections
# 20        PUT             /api/collections
# ...
